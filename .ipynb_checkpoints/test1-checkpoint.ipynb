# %%
import numpy as np
import scipy as sp

p = np.array([1, 2, 3])
print(p)
# Out:
# [1 2 3]

# %%
c = np.array([1, 2, 3, 4, 5])
d = c ** 2
print(d)
# Out:
# [ 1  4  9 16 25]

# %%
# Build a vector of 10000 normal deviates with variance 0.5^2 and mean 2
mu, sigma = 0, 1
v = np.random.normal(mu,sigma,10000)
(n, bins) = np.histogram(v, bins=50, normed=True)  
print(n)
print(bins)
# Out:
# [ 0.00274726  0.00137363  0.00274726  0.00343407  0.0048077   0.00412089
#   0.01098903  0.0192308   0.03159346  0.03983523  0.05219789  0.05837922
#   0.08722542  0.09478038  0.14079694  0.17170359  0.19780253  0.23901139
#   0.28846203  0.28914884  0.3495885   0.37225338  0.40796772  0.38873692
#   0.41826994  0.40728091  0.37156656  0.36126435  0.34684125  0.28914884
#   0.26442352  0.23763776  0.19917616  0.15728049  0.1387365   0.11126392
#   0.09615401  0.05769241  0.04464293  0.0288462   0.02678576  0.01579673
#   0.01373629  0.00824177  0.00618133  0.00274726  0.00274726  0.00068681
#   0.00068681  0.00137363]
# [-3.55011454 -3.40451479 -3.25891504 -3.11331528 -2.96771553 -2.82211577
#  -2.67651602 -2.53091627 -2.38531651 -2.23971676 -2.094117   -1.94851725
#  -1.8029175  -1.65731774 -1.51171799 -1.36611823 -1.22051848 -1.07491873
#  -0.92931897 -0.78371922 -0.63811946 -0.49251971 -0.34691996 -0.2013202
# ...

# %%
import numpy as np
import timeit
normal_py_sec = timeit.timeit('sum(x*x for x in range(1000))', number=10000)
naive_np_sec = timeit.timeit('sum(na*na)', setup="import numpy as np; na=np.arange(1000)", number=10000)
good_np_sec = timeit.timeit('na.dot(na)', setup="import numpy as np; na=np.arange(1000)",number=10000)
print("Normal Python: %f sec"%normal_py_sec)
print("Naive NumPy: %f sec"%naive_np_sec)
print("Good NumPy: %f sec"%good_np_sec)
# Out:
# Normal Python: 0.872681 sec
# Naive NumPy: 0.843907 sec
# Good NumPy: 0.012502 sec

# %%
import scipy as sp
data = sp.genfromtxt("../BuildingMachineLearningSystemsWithPython/ch01/data/web_traffic.tsv", delimiter="\t")
print(data.shape)
sp.sum(sp.isnan(data[:,1]))
x=data[:,0]
y=data[:,1]
x = x[~sp.isnan(y)]
y = y[~sp.isnan(y)]
# Out:
# (743, 2)

# %%
import matplotlib.pyplot as plt
plt.scatter(x,y)
plt.title("Web traffic over the last month")
plt.xlabel("Time")
plt.ylabel("Hits/hour")
plt.xticks([w*7*24 for w in range(10)],
['week %i'%w for w in range(10)])
plt.autoscale(tight=True)
plt.grid()
plt.show()

# %%
from matplotlib import pyplot as plt
from sklearn.datasets import load_iris
import numpy as np
data = load_iris()
features = data['data']
feature_names = data['feature_names']
target = data['target']
for t,marker,c in zip(range(3),">ox","rgb"):
    # We plot each class on its own to get different colored markers
    plt.scatter(features[target == t,0], features[target == t,1], marker=marker, c=c)
plt.title("IRIS Dataset features")
plt.xlabel("feature-0")
plt.ylabel("feature-1")
plt.show()

plength = features[:, 2]
# use numpy operations to get setosa features
is_setosa = (target == 0)
# This is the important step:
max_setosa =plength[is_setosa].max()
min_non_setosa = plength[~is_setosa].min()
print('Maximum of setosa: {0}.'.format(max_setosa))
print('Minimum of others: {0}.'.format(min_non_setosa))

#if features[:,2] < 2: 
#    print ('Iris Setosa')
#else:
#    print ('Iris Virginica or Iris Versicolour')
# Out:
# Maximum of setosa: 1.9.
# Minimum of others: 3.0.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-7da0e05f42b2> in <module>()
#      23 print('Minimum of others: {0}.'.format(min_non_setosa))
#      24
# ---> 25 if features[:,2] < 2:
#      26     print ('Iris Setosa')
#      27 else:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
import scipy as sp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv('../kidsmeasurements.csv', sep=' ')
df['DateS'] = df['Date'].astype(str)
#print(df)

#print (df[df['Name'] == 'Nikita'])
#fig, axes = plt.subplots(nrows=2, ncols=1)
fig, ax = plt.subplots(nrows=2, ncols=2)
for i, c in enumerate(('Nikita', 'Hanshal')):
    df1=df[df['Name'] == c]
    print (df1['Height'])
    x1=(df1['Date'] - 20110101)
    x2 = (x1 / 100 )*30+x1 %100
    y=df1['Height']
    x=df1['DateS']
    #ax.bar(x,y, width=100)
    #ax.set_xticks(x)
    #ax.set_xticklabels(x)
    #y.plot(kind='bar', ax=axes[i], figsize=(12, 10), title=c)
    plt.figure(1, figsize=(9, 3))
    plt.subplot(131)
    plt.bar(x, y)
    plt.subplot(132)
    plt.scatter(x, y)
    plt.subplot(133)
    plt.plot(x, y)
    plt.suptitle(c)
    plt.show()
    
#plt.show()
    #df1['Height'].plot(kind='bar', ax=axes[i], figsize=(12, 10), title=c)
    #plt.bar(df1['Height'])
#plt.show()
#plt.savefig('EU1.png', bbox_inches='tight')

plt.figure(1, figsize=(9, 3))
y=df1['Height']
x=df1['DateS']
plt.subplot(131)
plt.bar(x, y)
plt.subplot(132)
plt.scatter(x, y)
plt.subplot(133)
plt.plot(x, y)
plt.suptitle('Categorical Plotting')
plt.show()
# Out:
# 0     50.0
# 1     47.5
# 2     42.0
# 3     43.0
# 4     42.0
# 5     41.5
# 6     41.5
# 7     41.0
# 8     40.0
# 9     40.0
# 10    36.0
# Name: Height, dtype: float64
# 11    43.5
# 12    42.0
# 13    34.0
# 14    30.0
# 15    29.0
# 16    28.5
# 17    27.5
# 18    27.5
# 19    25.5
# 20    24.0
# Name: Height, dtype: float64
